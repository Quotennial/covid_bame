# %%
import sys
sys.path.insert(0, '../src/data')
import main
# Out:
# Found local clean copy
# Found local clean copy

# %%
main.fbook_covid_data.df
# Out:
#     Number of confirmed COVID-19 cases (cumulative total) by date of test results  \
# 0                                               London
# 1                                               London
# 2                                               London
# 3                                               London
# 4                                               London
# ..                                                 ...
# 365                                              Wales
# 366                                              Wales
# 367                                              Wales
# 368                                              Wales
# 369                                              Wales
#
#      UTLA Code  \
# 0    E09000002
# 1    E09000003
# 2    E09000004
# 3    E09000005
# 4    E09000006
# ..         ...
# 365        NaN
# 366        NaN
# 367        NaN
# 368        NaN
# 369        NaN
#
# ...
